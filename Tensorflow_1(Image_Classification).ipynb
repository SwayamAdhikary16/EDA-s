# %% [markdown]
# <a href="https://colab.research.google.com/github/SwayamAdhikary16/EDA-s/blob/main/Tensorflow_1(Image_Classification).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -Uqqq pip
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 23.5 MB/s eta 0:00:00

# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
import matplotlib.pyplot as plt

# %%
data = keras.datasets.fashion_mnist

# %%
(train_images,train_labels),(test_images,test_labels) = data.load_data()
# Out:
# ...
# 4422102/4422102 [==============================] - 0s 0us/step

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
train_images = train_images/255.0
test_images = test_images/255.0

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28,28)),
    keras.layers.Dense(128,activation = "relu"),
    keras.layers.Dense(10,activation = "softmax"),
])

# %%
model.compile(optimizer = "adam",loss = "sparse_categorical_crossentropy",metrics = ["accuracy"])

# %%
model.fit(train_images,train_labels,epochs = 50)
# Out:
# Epoch 1/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2311 - accuracy: 0.9139
# Epoch 2/50
# 1875/1875 [==============================] - 12s 6ms/step - loss: 0.2237 - accuracy: 0.9174
# Epoch 3/50
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.2150 - accuracy: 0.9201
# Epoch 4/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.2103 - accuracy: 0.9215
# Epoch 5/50
# 1875/1875 [==============================] - 10s 5ms/step - loss: 0.2046 - accuracy: 0.9238
# Epoch 6/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1989 - accuracy: 0.9265
# Epoch 7/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1936 - accuracy: 0.9270
# Epoch 8/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1882 - accuracy: 0.9302
# Epoch 9/50
# 1875/1875 [==============================] - 7s 4ms/step - loss: 0.1846 - accuracy: 0.9310
# Epoch 10/50
# ...

# %%
test_loss,test_acc = model.evaluate(test_images,test_labels)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.5758 - accuracy: 0.8818

# %%
prediction = model.predict(test_images)
print(class_names[np.argmax(prediction[0])])
# Out:
# 313/313 [==============================] - 1s 2ms/step
# Ankle boot

# %%
for i in range(10):
  plt.grid(False)
  plt.imshow(test_images[i],cmap = plt.cm.binary)
  plt.xlabel("Actual:" + class_names[test_labels[i]])
  plt.title("Prediction:"+ class_names[np.argmax(prediction[i])])
  plt.show()
